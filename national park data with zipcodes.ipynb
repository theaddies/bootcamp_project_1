# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import datetime
import re

csv_file = 'national_parks.csv'
csv_clean = 'national_parks_clean.csv'

csv_clean_zip = 'national_parks_clean_with_zip.csv'
#national park
national_park_key = 'GkpWhu2NMmW3ByYQQBG7EUil39dXzp0CSSkZhYMr'
national_park_key_2 = 'D9gmnm3IkygXozEzcTJBGklkEslRpu3QdL3h3dIH'
national_park_key_3 = 'h21YkFpooH9YM3c3Rqv9Qg19I3FclWVQUf4RQo2i'
#national park
national_park_key_4 = '9hB1XUMrVFU13qYeM6boLkETee0C5ebMu3yE4hrN'
base_url = 'https://developer.nps.gov/api/v1/'

# %%
park_df = pd.read_csv(csv_clean)
park_df
# Out:
#                             Name                   Location  \
# 0                         Acadia                      Maine
# 1                         Arches                       Utah
# 2                       Badlands               South Dakota
# 3                       Big Bend                      Texas
# 4                       Biscayne                    Florida
# 5   Black Canyon of The Gunnison                   Colorado
# 6                   Bryce Canyon                       Utah
# 7                    Canyonlands                       Utah
# 8                   Capitol Reef                       Utah
# 9               Carlsbad Caverns                 New Mexico
# 10               Channel Islands                 California
# 11                      Congaree             South Carolina
# 12                   Crater Lake                     Oregon
# 13               Cuyahoga Valley                       Ohio
# 14                  Death Valley         California, Nevada
# ...

# %%
park_df['postalCode'] = 0

# %%
for i in range(len(park_df)):
    parkCode = park_df.loc[i , 'Park Code']
    full_url = base_url + 'parks?&parkCode=' + parkCode + '&api_key='+ national_park_key_4
    print(full_url)
    response=requests.get(full_url).json()
    park_df.loc[i, 'postalCode'] = response['data'][0]['addresses'][0]['postalCode']
# Out:
# https://developer.nps.gov/api/v1/parks?&parkCode=acad&api_key=9hB1XUMrVFU13qYeM6boLkETee0C5ebMu3yE4hrN
# https://developer.nps.gov/api/v1/parks?&parkCode=arch&api_key=9hB1XUMrVFU13qYeM6boLkETee0C5ebMu3yE4hrN
# https://developer.nps.gov/api/v1/parks?&parkCode=badl&api_key=9hB1XUMrVFU13qYeM6boLkETee0C5ebMu3yE4hrN
# https://developer.nps.gov/api/v1/parks?&parkCode=bibe&api_key=9hB1XUMrVFU13qYeM6boLkETee0C5ebMu3yE4hrN
# https://developer.nps.gov/api/v1/parks?&parkCode=bisc&api_key=9hB1XUMrVFU13qYeM6boLkETee0C5ebMu3yE4hrN
# https://developer.nps.gov/api/v1/parks?&parkCode=blca&api_key=9hB1XUMrVFU13qYeM6boLkETee0C5ebMu3yE4hrN
# https://developer.nps.gov/api/v1/parks?&parkCode=brca&api_key=9hB1XUMrVFU13qYeM6boLkETee0C5ebMu3yE4hrN
# https://developer.nps.gov/api/v1/parks?&parkCode=cany&api_key=9hB1XUMrVFU13qYeM6boLkETee0C5ebMu3yE4hrN
# https://developer.nps.gov/api/v1/parks?&parkCode=care&api_key=9hB1XUMrVFU13qYeM6boLkETee0C5ebMu3yE4hrN
# ...

# %%
full_url = base_url + 'parks?&parkCode=' + parkCode + '&api_key='+ national_park_key_4
print(full_url)
response=requests.get(full_url).json()
# Out:
# https://developer.nps.gov/api/v1/parks?&parkCode=zion&api_key=9hB1XUMrVFU13qYeM6boLkETee0C5ebMu3yE4hrN

# %%
response['data'][0]['addresses'][0]['postalCode']
# Out:
# '84767'

# %%
park_df
# Out:
#                             Name                   Location  \
# 0                         Acadia                      Maine
# 1                         Arches                       Utah
# 2                       Badlands               South Dakota
# 3                       Big Bend                      Texas
# 4                       Biscayne                    Florida
# 5   Black Canyon of The Gunnison                   Colorado
# 6                   Bryce Canyon                       Utah
# 7                    Canyonlands                       Utah
# 8                   Capitol Reef                       Utah
# 9               Carlsbad Caverns                 New Mexico
# 10               Channel Islands                 California
# 11                      Congaree             South Carolina
# 12                   Crater Lake                     Oregon
# 13               Cuyahoga Valley                       Ohio
# 14                  Death Valley         California, Nevada
# ...

# %%
park_df.to_csv(csv_clean_zip)
