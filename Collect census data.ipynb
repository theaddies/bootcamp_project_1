# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import datetime
import re
import gmaps
import os

# %%
url = 'https://api.census.gov/data/2018/acs/acs5?get=NAME,group(B19013)&for=zip%20code%20tabulation%20area:*'

# %%
response = requests.get(url).json()

# %%
response
# Out:
# [['NAME',
#   'GEO_ID',
#   'B19013_001E',
#   'B19013_001M',
#   'NAME',
#   'B19013_001MA',
#   'B19013_001EA',
#   'zip code tabulation area'],
#  ['ZCTA5 43964',
#   '8600000US43964',
#   '42826',
#   '3932',
#   'ZCTA5 43964',
#   None,
#   None,
#   '43964'],
#  ['ZCTA5 28216',
#   '8600000US28216',
#   '48647',
#   '2420',
#   'ZCTA5 28216',
#   None,
#   None,
#   '28216'],
#  ['ZCTA5 28277',
#   '8600000US28277',
#   '105885',
#   '2303',
#   'ZCTA5 28277',
#   None,
#   None,
#   '28277'],
#  ['ZCTA5 28278',
#   '8600000US28278',
#   '90282',
#   '6483',
#   'ZCTA5 28278',
#   None,
#   None,
#   '28278'],
#  ['ZCTA5 28303',
#   '8600000US28303',
#   '39896',
#   '2177',
#   'ZCTA5 28303',
#   None,
#   None,
#   '28303'],
#  ['ZCTA5 28314',
#   '8600000US28314',
#   '47873',
#   '1675',
#   'ZCTA5 28314',
#   None,
#   None,
#   '28314'],
#  ['ZCTA5 28330',
#   '8600000US28330',
#   '28472',
#   '19996',
#   'ZCTA5 28330',
#   None,
#   None,
#   '28330'],
# ...

# %%
Name = []
GEO_ID = []
median_household_income = []   #'B19013_001E'Median household income
margin_of_error = []    #B19013_001M, Margin of Error



zip_code = [] #'zip code tabulation area'
