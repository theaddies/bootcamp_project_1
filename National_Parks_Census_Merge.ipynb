# %%
import pandas as pd

# %%
###Other possible imports needed later
#from config import (census_key, gkey)
#import gmaps
#from census import Census
#import numpy as np
#import requests
#import time
#from scipy.stats import linregress
#from matplotlib import pyplot as plt

# %%
park_path = "../bootcamp_project_1/Resources/fake_national_park_data.csv"
census_path = "../bootcamp_project_1/Resources/fake_census_data.csv"

parks_df = pd.read_csv(park_path)
census_df = pd.read_csv(census_path)

# %%
combined_park_census_df = pd.merge(parks_df, census_df, how='outer', on = 'Zipcode')

#Change depending on data
combined_park_census_df = combined_park_census_df.drop(columns = ['Unnamed: 12'])
combined_park_census_df = combined_park_census_df.dropna()

combined_park_census_df.head()
# Out:
#                            Name        Location       coordinates    lat  \
# 0                        Acadia           Maine   44.35°N 68.21°W  44.35
# 1                American Samoa  American Samoa  14.25°S 170.68°W  14.25
# 6  Black Canyon of the Gunnison        Colorado  38.57°N 107.72°W  38.57
# 8                   Canyonlands            Utah   38.2°N 109.93°W  38.20
# 9                  Capitol Reef            Utah  38.20°N 111.17°W  38.20
#
#       lon  Zipcode Date established as park                     Area, acres  \
# 0  -68.21    46039                26-Feb-19     49,076.63 acres (198.6 km2)
# 1 -170.68    46340                31-Oct-88       8,256.67 acres (33.4 km2)
# 6 -107.72    47353                21-Oct-99     30,779.83 acres (124.6 km2)
# 8 -109.93    26743                12-Sep-64  337,597.83 acres (1,366.2 km2)
# 9 -111.17    26543                18-Dec-71    241,904.50 acres (979.0 km2)
#
#   area, acres area, km^2 Recreation visitors  \
# ...
