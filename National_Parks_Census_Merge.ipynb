# %%
import pandas as pd

# %%
###Other possible imports needed later
#from config import (census_key, gkey)
#import gmaps
#from census import Census
#import numpy as np
#import requests
#import time
#from scipy.stats import linregress
#from matplotlib import pyplot as plt

# %%
park_path = "../bootcamp_project_1/Resources/fake_national_park_data.csv"
census_path = "../bootcamp_project_1/Resources/fake_census_data.csv"

parks_df = pd.read_csv(park_path)
census_df = pd.read_csv(census_path)

# %%
combined_park_census_df = pd.merge(parks_df, census_df, how='outer', on = 'Zipcode')
 
combined_park_census_df.head()
# Out:
#              Name        Location       coordinates    lat     lon  Zipcode  \
# 0          Acadia           Maine   44.35°N 68.21°W  44.35  -68.21    46039
# 1  American Samoa  American Samoa  14.25°S 170.68°W  14.25 -170.68    46340
# 2          Arches            Utah  38.68°N 109.57°W  38.68 -109.57    44562
# 3        Badlands    South Dakota  43.75°N 102.50°W  43.75 -102.50    63814
# 4        Big Bend           Texas  29.25°N 103.25°W  29.25 -103.25    95263
#
#   Date established as park                     Area, acres area, acres  \
# 0                26-Feb-19     49,076.63 acres (198.6 km2)   49,076.63
# 1                31-Oct-88       8,256.67 acres (33.4 km2)    8,256.67
# 2                12-Nov-71     76,678.98 acres (310.3 km2)   76,678.98
# 3                10-Nov-78    242,755.94 acres (982.4 km2)  242,755.94
# 4                12-Jun-44  801,163.21 acres (3,242.2 km2)  801,163.21
#
#   area, km^2 Recreation visitors  \
# 0      198.6           3,537,575
# 1       33.4              28,626
# 2      310.3           1,663,557
# 3      982.4           1,008,942
# 4   3,242.20             440,091
#
#                                          Description  Unnamed: 12  Population  \
# 0  Covering most of Mount Desert Island and other...          NaN       843.0
# 1  The southernmost national park is on three Sam...          NaN      1093.0
# 2  This site features more than 2,000 natural san...          NaN         NaN
# 3  The Badlands are a collection of buttes, pinna...          NaN         NaN
# 4  Named for the prominent bend in the Rio Grande...          NaN         NaN
#
#    Median Age  Household Income  Per Capita Income  Poverty Count  \
# 0        39.2           62344.0            24915.0           50.0
# 1        35.4           75587.0            26145.0          141.0
# 2         NaN               NaN                NaN            NaN
# 3         NaN               NaN                NaN            NaN
# 4         NaN               NaN                NaN            NaN
#
#    Poverty Rate
# 0      5.931198
# 1     12.900274
# 2           NaN
# 3           NaN
# 4           NaN
