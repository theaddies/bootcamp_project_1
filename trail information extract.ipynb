# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import datetime
csv_np_input = 'national_parks_clean.csv'
# Import API key
from config import api_key

# %% [markdown]
# Method: getTrails
#
# Returns trails for a given query.
#
# Required Arguments:
#
# key - Your private key
#
# lat - Latitude for a given area
#
# lon - Longitude for a given area
#
# Optional Arguments:
#
# maxDistance - Max distance, in miles, from lat, lon. Default: 30. Max: 200.
#
# maxResults - Max number of trails to return. Default: 10. Max: 500.
#
# sort - Values can be 'quality', 'distance'. Default: quality.
#
# minLength - Min trail length, in miles. Default: 0 (no minimum).
#
# minStars - Min star rating, 0-4. Default: 0.
#
# Example:
#
# https://www.hikingproject.com/data/get-trails?lat=40.0274&lon=-105.2519&maxDistance=10&key=200374562-8acd37f44e1bf5bdb6381ee96b8ab81a
#
# Notes:
#
# All returned fields will always be defined, but optional fields may be empty.

# %%
park_df = pd.read_csv(csv_np_input)

# %%
park_df
# Out:
#                   Name                 Location       coordinates    lat  \
# 0               Acadia                    Maine   44.35°N 68.21°W  44.35
# 1       American Samoa           American Samoa  14.25°S 170.68°W -14.25
# 2               Arches                     Utah  38.68°N 109.57°W  38.68
# 3             Badlands             South Dakota  43.75°N 102.50°W  43.75
# 4             Big Bend                    Texas  29.25°N 103.25°W  29.25
# ..                 ...                      ...               ...    ...
# 57           Wind Cave             South Dakota  43.57°N 103.48°W  43.57
# 58  Wrangell–St. Elias                   Alaska  61.00°N 142.00°W  61.00
# 59         Yellowstone  Wyoming, Montana, Idaho  44.60°N 110.50°W  44.60
# 60            Yosemite               California  37.83°N 119.50°W  37.83
# 61                Zion                     Utah  37.30°N 113.05°W  37.30
#
#        lon Date established as park[5][10]                    Area (2019)[11]  \
# 0   -68.21                       26-Feb-19        49,076.63 acres (198.6 km2)
# 1  -170.68                       31-Oct-88          8,256.67 acres (33.4 km2)
# 2  -109.57                       12-Nov-71        76,678.98 acres (310.3 km2)
# 3  -102.50                       10-Nov-78       242,755.94 acres (982.4 km2)
# 4  -103.25                       12-Jun-44     801,163.21 acres (3,242.2 km2)
# ..     ...                             ...                                ...
# 57 -103.48                        9-Jan-03        33,970.84 acres (137.5 km2)
# 58 -142.00                        2-Dec-80  8,323,146.48 acres (33,682.6 km2)
# 59 -110.50                   March 1, 1872   2,219,790.71 acres (8,983.2 km2)
# 60 -119.50                 October 1, 1890     761,747.50 acres (3,082.7 km2)
# 61 -113.05                       19-Nov-19       147,242.66 acres (595.9 km2)
#
#      area, acres area, km^2 Recreation visitors (2018)[8]  \
# 0      49,076.63      198.6                     3,537,575
# 1       8,256.67       33.4                        28,626
# 2      76,678.98      310.3                     1,663,557
# 3     242,755.94      982.4                     1,008,942
# 4     801,163.21    3,242.2                       440,091
# ..           ...        ...                           ...
# 57     33,970.84      137.5                       656,397
# 58  8,323,146.48   33,682.6                        79,450
# 59  2,219,790.71    8,983.2                     4,115,000
# 60    761,747.50    3,082.7                     4,009,436
# 61    147,242.66      595.9                     4,320,033
#
#                                           Description
# 0   Covering most of Mount Desert Island and other...
# 1   The southernmost national park is on three Sam...
# 2   This site features more than 2,000 natural san...
# 3   The Badlands are a collection of buttes, pinna...
# 4   Named for the prominent bend in the Rio Grande...
# ..                                                ...
# 57  Wind Cave is distinctive for its calcite fin f...
# 58  An over 8 million acres (32,375 km2) plot of m...
# 59  Situated on the Yellowstone Caldera, the park ...
# 60  Yosemite features sheer granite cliffs, except...
# 61  Located at the junction of the Colorado Platea...
#
# [62 rows x 11 columns]

# %%
#https://www.hikingproject.com/data/get-trails?lat=40.0274&lon=-105.2519&maxDistance=10&key=200374562-8acd37f44e1bf5bdb6381ee96b8ab81a

# %%
trail_id = []
name = []
trail_type = []
summary = []
difficulty = []
stars = []
starVotes = []
location = []
url = []
imgSqSmall = []
imgSmall = []
imgSmallMed = []
imgMedium = []
length = []
ascent = []
descent = []
high = []
low = []
longitude = []
latitude = []
conditionStatus = []
conditionDetails = []
conditionDate = []

# %%
base_url = 'https://www.hikingproject.com/data/get-trails?'
lat = 41.5
lon = -81.44
maxDistance = 200
maxResults = 5
full_url = base_url + 'lat='+str(lat) + '&lon=' + str(lon)+'&maxDistance='+str(maxDistance)+'&maxResults=' + str(maxResults) + '&key='+ api_key 
print(full_url)
response=requests.get(full_url).json()
response
# Out:
# https://www.hikingproject.com/data/get-trails?lat=41.5&lon=-81.44&maxDistance=200&maxResults=5&key=200374562-8acd37f44e1bf5bdb6381ee96b8ab81a
# {'trails': [{'id': 7005158,
#    'name': 'Zaleski Backpack Trail South Loop',
#    'type': 'Recommended Route',
#    'summary': 'Escape the Hocking Hills crowds and explore this rare gem in southern Ohio.',
#    'difficulty': 'blueBlack',
#    'stars': 4.3,
#    'starVotes': 53,
#    'location': 'Athens, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7005158/zaleski-backpack-trail-south-loop',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7068673_sqsmall_1585660045.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7068673_small_1585660045.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7068673_smallMed_1585660045.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7068673_medium_1585660045.jpg',
#    'length': 10.3,
#    'ascent': 955,
#    'descent': -956,
#    'high': 1014,
#    'low': 715,
#    'longitude': -82.341,
#    'latitude': 39.3311,
#    'conditionStatus': 'Minor Issues',
#    'conditionDetails': 'Muddy, Fallen Trees - overgrown, parts of path literally under water.',
#    'conditionDate': '2020-06-07 10:26:47'},
#   {'id': 7017937,
#    'name': 'Brandywine Falls Loop',
#    'type': 'Recommended Route',
#    'summary': "Enjoy a scenic tour of the area surrounding one of Cuyahoga's top attractions.",
#    'difficulty': 'greenBlue',
#    'stars': 4.4,
#    'starVotes': 47,
#    'location': 'Boston Heights, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7017937/brandywine-falls-loop',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7018093_sqsmall_1554830303.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7018093_small_1554830303.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7018093_smallMed_1554830303.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7018093_medium_1554830303.jpg',
#    'length': 1.4,
#    'ascent': 179,
#    'descent': -180,
#    'high': 857,
#    'low': 695,
#    'longitude': -81.54,
#    'latitude': 41.2767,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2020-06-16 09:38:21'},
#   {'id': 7016992,
#    'name': 'Ledges to Pine Grove Loop',
#    'type': 'Recommended Route',
#    'summary': "See one of CVNP's most iconic trails plus a little-known loop.",
#    'difficulty': 'blue',
#    'stars': 4.5,
#    'starVotes': 47,
#    'location': 'Boston Heights, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016992/ledges-to-pine-grove-loop',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7015930_sqsmall_1554827046.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7015930_small_1554827046.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7015930_smallMed_1554827046.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7015930_medium_1554827046.jpg',
#    'length': 4,
#    'ascent': 230,
#    'descent': -232,
#    'high': 1054,
#    'low': 881,
#    'longitude': -81.5106,
#    'latitude': 41.224,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2020-06-15 11:43:05'},
#   {'id': 7005046,
#    'name': 'Potawatomi Trail',
#    'type': 'Recommended Route',
#    'summary': 'A classic SE Michigan loop that makes for a beautiful hike.',
#    'difficulty': 'blue',
#    'stars': 4.6,
#    'starVotes': 39,
#    'location': 'Pinckney, Michigan',
#    'url': 'https://www.hikingproject.com/trail/7005046/potawatomi-trail',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7029423_sqsmall_1554924492.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7029423_small_1554924492.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7029423_smallMed_1554924492.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7029423_medium_1554924492.jpg',
#    'length': 17.5,
#    'ascent': 787,
#    'descent': -783,
#    'high': 995,
#    'low': 883,
#    'longitude': -83.9638,
#    'latitude': 42.4155,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': '',
#    'conditionDate': '2020-05-30 10:07:43'},
#   {'id': 7017137,
#    'name': 'Morrison and Rimrock Trails',
#    'type': 'Recommended Route',
#    'summary': 'A beautiful and challenging trek with great views of the Allegheny Reservoir.',
#    'difficulty': 'blueBlack',
#    'stars': 4.6,
#    'starVotes': 20,
#    'location': 'Warren, Pennsylvania',
#    'url': 'https://www.hikingproject.com/trail/7017137/morrison-and-rimrock-trails',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7039567_sqsmall_1555092205.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7039567_small_1555092205.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7039567_smallMed_1555092205.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7039567_medium_1555092205.jpg',
#    'length': 14,
#    'ascent': 1609,
#    'descent': -1603,
#    'high': 2085,
#    'low': 1392,
#    'longitude': -78.8969,
#    'latitude': 41.8613,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'}],
#  'success': 1}

# %%
test = response['trails'][0]['summary']
print(test)
# Out:
# Escape the Hocking Hills crowds and explore this rare gem in southern Ohio.

# %%
response['trails'][0]['summary']
# Out:
# 'Escape the Hocking Hills crowds and explore this rare gem in southern Ohio.'

# %%
for i in range(len(response['trails'])):
    print(i)
    trail_id.append(response['trails'][i]['id'])
    name.append(response['trails'][i]['name'])
    trail_type.append(response['trails'][i]['type'])
    summary.append(response['trails'][i]['summary'])
    difficulty.append(response['trails'][i]['difficulty'])
    stars.append(response['trails'][i]['stars'])
    starVotes.append(response['trails'][i]['starVotes'])
    location.append(response['trails'][i]['location'])
    url.append(response['trails'][i]['url'])
    imgSqSmall.append(response['trails'][i]['imgSqSmall'])
    imgSmall.append(response['trails'][i]['imgSmall'])
    imgSmallMed.append(response['trails'][i]['imgSmallMed'])
    imgMedium.append(response['trails'][i]['imgMedium'])
    length.append(response['trails'][i]['length'])
    ascent.append(response['trails'][i]['ascent'])
    descent.append(response['trails'][i]['descent'])
    high.append(response['trails'][i]['high'])
    low.append(response['trails'][i]['low'])
    longitude.append(response['trails'][i]['longitude'])
    latitude.append(response['trails'][i]['latitude'])
    conditionStatus.append(response['trails'][i]['conditionStatus'])
    conditionDetails.append(response['trails'][i]['conditionDetails'])
    conditionDate.append(response['trails'][i]['conditionDate'])
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
length
# Out:
# [10.3, 1.4, 4, 17.5, 14]

# %%
trail_df = pd.DataFrame()

# %%
trail_df = pd.DataFrame({'trail_id': trail_id,
'name' : name,
'trail_type' : trail_type,
'summary' : summary,
'difficulty' : difficulty,
'stars' : stars,
'starVotes' : starVotes,
'location' : location,
'url': url,
'imgSqSmall' : imgSqSmall,
'imgSmall' : imgSmall,
'imgSmallMed' : imgSmallMed,
'imgMedium' : imgMedium,
'length, miles' : length,
'ascent, ft': ascent,
'descent, ft' : descent,
'high, ft' : high,
'low, ft': low,
'longitude' : longitude,
'latitude' : latitude,
'conditionStatus' : conditionStatus,
'conditionDetails' : conditionDetails,
'conditionDate' : conditionDate})

# %%
trail_df
# Out:
#    trail_id                               name         trail_type  \
# 0   7005158  Zaleski Backpack Trail South Loop  Recommended Route
# 1   7017937              Brandywine Falls Loop  Recommended Route
# 2   7016992          Ledges to Pine Grove Loop  Recommended Route
# 3   7005046                   Potawatomi Trail  Recommended Route
# 4   7017137        Morrison and Rimrock Trails  Recommended Route
#
#                                              summary difficulty  stars  \
# 0  Escape the Hocking Hills crowds and explore th...  blueBlack    4.3
# 1  Enjoy a scenic tour of the area surrounding on...  greenBlue    4.4
# 2  See one of CVNP's most iconic trails plus a li...       blue    4.5
# 3  A classic SE Michigan loop that makes for a be...       blue    4.6
# 4  A beautiful and challenging trek with great vi...  blueBlack    4.6
#
#    starVotes              location  \
# 0         53          Athens, Ohio
# 1         47  Boston Heights, Ohio
# 2         47  Boston Heights, Ohio
# 3         39    Pinckney, Michigan
# 4         20  Warren, Pennsylvania
#
#                                                  url  \
# 0  https://www.hikingproject.com/trail/7005158/za...
# 1  https://www.hikingproject.com/trail/7017937/br...
# 2  https://www.hikingproject.com/trail/7016992/le...
# 3  https://www.hikingproject.com/trail/7005046/po...
# 4  https://www.hikingproject.com/trail/7017137/mo...
#
#                                           imgSqSmall  ... length, miles  \
# 0  https://cdn2.apstatic.com/photos/hike/7068673_...  ...          10.3
# 1  https://cdn2.apstatic.com/photos/hike/7018093_...  ...           1.4
# 2  https://cdn2.apstatic.com/photos/hike/7015930_...  ...           4.0
# 3  https://cdn2.apstatic.com/photos/hike/7029423_...  ...          17.5
# 4  https://cdn2.apstatic.com/photos/hike/7039567_...  ...          14.0
#
#   ascent, ft descent, ft  high, ft  low, ft  longitude  latitude  \
# 0        955        -956      1014      715   -82.3410   39.3311
# 1        179        -180       857      695   -81.5400   41.2767
# 2        230        -232      1054      881   -81.5106   41.2240
# 3        787        -783       995      883   -83.9638   42.4155
# 4       1609       -1603      2085     1392   -78.8969   41.8613
#
#    conditionStatus                                   conditionDetails  \
# 0     Minor Issues  Muddy, Fallen Trees - overgrown, parts of path...
# 1        All Clear                                                Dry
# 2        All Clear                                                Dry
# 3        All Clear
# 4          Unknown                                               None
#
#          conditionDate
# 0  2020-06-07 10:26:47
# 1  2020-06-16 09:38:21
# 2  2020-06-15 11:43:05
# 3  2020-05-30 10:07:43
# 4  1970-01-01 00:00:00
#
# [5 rows x 23 columns]

# %%
response['trails'][0]
# Out:
# {'id': 7005158,
#  'name': 'Zaleski Backpack Trail South Loop',
#  'type': 'Recommended Route',
#  'summary': 'Escape the Hocking Hills crowds and explore this rare gem in southern Ohio.',
#  'difficulty': 'blueBlack',
#  'stars': 4.3,
#  'starVotes': 53,
#  'location': 'Athens, Ohio',
#  'url': 'https://www.hikingproject.com/trail/7005158/zaleski-backpack-trail-south-loop',
#  'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7068673_sqsmall_1585660045.jpg',
#  'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7068673_small_1585660045.jpg',
#  'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7068673_smallMed_1585660045.jpg',
#  'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7068673_medium_1585660045.jpg',
#  'length': 10.3,
#  'ascent': 955,
#  'descent': -956,
#  'high': 1014,
#  'low': 715,
#  'longitude': -82.341,
#  'latitude': 39.3311,
#  'conditionStatus': 'Minor Issues',
#  'conditionDetails': 'Muddy, Fallen Trees - overgrown, parts of path literally under water.',
#  'conditionDate': '2020-06-07 10:26:47'}

# %%
trail_df = pd.response
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-efbd37179464> in <module>
# ----> 1 trail_df = pd.response
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     261             return _SparseArray
#     262
# --> 263         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     264
#     265
#
# AttributeError: module 'pandas' has no attribute 'response'

# %%
park_df

# %%
response = requests.get(https://www.hikingproject.com/data/get-trails?lat='40.0274'&lon='-105.2519'&maxDistance='10'&key='200374562-8acd37f44e1bf5bdb6381ee96b8ab81a').json()
