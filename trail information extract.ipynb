# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import datetime
csv_np_input = 'national_parks_clean.csv'
# Import API key
from config import api_key

# %% [markdown]
# Method: getTrails
#
# Returns trails for a given query.
#
# Required Arguments:
#
# key - Your private key
#
# lat - Latitude for a given area
#
# lon - Longitude for a given area
#
# Optional Arguments:
#
# maxDistance - Max distance, in miles, from lat, lon. Default: 30. Max: 200.
#
# maxResults - Max number of trails to return. Default: 10. Max: 500.
#
# sort - Values can be 'quality', 'distance'. Default: quality.
#
# minLength - Min trail length, in miles. Default: 0 (no minimum).
#
# minStars - Min star rating, 0-4. Default: 0.
#
# Example:
#
# https://www.hikingproject.com/data/get-trails?lat=40.0274&lon=-105.2519&maxDistance=10&key=200374562-8acd37f44e1bf5bdb6381ee96b8ab81a
#
# Notes:
#
# All returned fields will always be defined, but optional fields may be empty.

# %%
park_df = pd.read_csv(csv_np_input)

# %%
park_df[park_df['Name'] == 'Acadia']
# Out:
#      Name Location      coordinates    lat    lon Date established as park  \
# 0  Acadia    Maine  44.35°N 68.21°W  44.35 -68.21                26-Feb-19
#
#                    Area, acres area, acres area, km^2 Recreation visitors  \
# 0  49,076.63 acres (198.6 km2)   49,076.63      198.6           3,537,575
#
#                                          Description
# 0  Covering most of Mount Desert Island and other...

# %%
#### find a particular park
park_to_find = 'Cuyahoga Valley'
#get surface are of park
area_km2 = park_df.loc[park_df['Name'] == park_to_find, 'area, km^2'].to_numpy().astype('float64')[0]
area_km2
# Out:
# 131.8

# %%
# determine approximate radius of park
park_radius_km = np.sqrt(area_km2 / np.pi)
park_radius_km
# Out:
# 6.477132312916235

# %%
#set trail search area to be 2 x the radius of the park area
maxDistance = 2 * park_radius_km / 1.61
maxDistance
# Out:
# 8.046127096790354

# %%
lat = park_df.loc[park_df['Name'] == park_to_find, 'lat'].to_numpy().astype('float32')[0]
lon = park_df.loc[park_df['Name'] == park_to_find, 'lon'].to_numpy().astype('float32')[0]
print(lat, lon)
# Out:
# 41.24 -81.55

# %%
#https://www.hikingproject.com/data/get-trails?lat=40.0274&lon=-105.2519&maxDistance=10&key=200374562-8acd37f44e1bf5bdb6381ee96b8ab81a

# %%
trail_id = []
name = []
trail_type = []
summary = []
difficulty = []
stars = []
starVotes = []
location = []
url = []
imgSqSmall = []
imgSmall = []
imgSmallMed = []
imgMedium = []
length = []
ascent = []
descent = []
high = []
low = []
longitude = []
latitude = []
conditionStatus = []
conditionDetails = []
conditionDate = []

# %%
base_url = 'https://www.hikingproject.com/data/get-trails?'
#lat = 44.35
#lon = -81.44
#maxDistance = 200
maxResults = 500
sort = 'distance' #can be 'quality' or 'distance'
minLength = 0
minStars = 0
full_url = base_url + 'lat='+str(lat) + '&lon=' + str(lon)+'&maxDistance='+str(maxDistance)+'&minLength='+str(minLength)+'&minStars='+str(minStars)+'&sort='+sort+'&maxResults=' + str(maxResults) + '&key='+ api_key 
print(full_url)
response=requests.get(full_url).json()
response
# Out:
# https://www.hikingproject.com/data/get-trails?lat=41.24&lon=-81.55&maxDistance=8.046127096790354&minLength=0&minStars=0&sort=distance&maxResults=500&key=200374562-8acd37f44e1bf5bdb6381ee96b8ab81a
# {'trails': [{'id': 7013161,
#    'name': 'Blue Hen Falls Trail',
#    'type': 'Recommended Route',
#    'summary': 'An out-and-back trail that follows a creek between two waterfalls.',
#    'difficulty': 'blue',
#    'stars': 4.2,
#    'starVotes': 27,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7013161/blue-hen-falls-trail',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7010452_sqsmall_1554398524.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7010452_small_1554398524.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7010452_smallMed_1554398524.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7010452_medium_1554398524.jpg',
#    'length': 1.2,
#    'ascent': 146,
#    'descent': -147,
#    'high': 879,
#    'low': 732,
#    'longitude': -81.5726,
#    'latitude': 41.257,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Mostly Dry, Some Mud',
#    'conditionDate': '2020-06-14 11:59:04'},
#   {'id': 7017937,
#    'name': 'Brandywine Falls Loop',
#    'type': 'Recommended Route',
#    'summary': "Enjoy a scenic tour of the area surrounding one of Cuyahoga's top attractions.",
#    'difficulty': 'greenBlue',
#    'stars': 4.4,
#    'starVotes': 47,
#    'location': 'Boston Heights, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7017937/brandywine-falls-loop',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7018093_sqsmall_1554830303.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7018093_small_1554830303.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7018093_smallMed_1554830303.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7018093_medium_1554830303.jpg',
#    'length': 1.4,
#    'ascent': 179,
#    'descent': -180,
#    'high': 857,
#    'low': 695,
#    'longitude': -81.54,
#    'latitude': 41.2767,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2020-06-16 09:38:21'},
#   {'id': 7016992,
#    'name': 'Ledges to Pine Grove Loop',
#    'type': 'Recommended Route',
#    'summary': "See one of CVNP's most iconic trails plus a little-known loop.",
#    'difficulty': 'blue',
#    'stars': 4.5,
#    'starVotes': 47,
#    'location': 'Boston Heights, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016992/ledges-to-pine-grove-loop',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7015930_sqsmall_1554827046.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7015930_small_1554827046.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7015930_smallMed_1554827046.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7015930_medium_1554827046.jpg',
#    'length': 4,
#    'ascent': 230,
#    'descent': -232,
#    'high': 1054,
#    'low': 881,
#    'longitude': -81.5106,
#    'latitude': 41.224,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2020-06-15 11:43:05'},
#   {'id': 7015894,
#    'name': 'Deer Lick Cave Loop Trail',
#    'type': 'Recommended Route',
#    'summary': 'A wooded loop around the Brecksville Reservation that includes multiple creeks.',
#    'difficulty': 'blue',
#    'stars': 4.1,
#    'starVotes': 20,
#    'location': 'Brecksville, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7015894/deer-lick-cave-loop-trail',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7016916_sqsmall_1554828528.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7016916_small_1554828528.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7016916_smallMed_1554828528.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7016916_medium_1554828528.jpg',
#    'length': 3.7,
#    'ascent': 480,
#    'descent': -484,
#    'high': 858,
#    'low': 657,
#    'longitude': -81.6092,
#    'latitude': 41.3054,
#    'conditionStatus': 'Minor Issues',
#    'conditionDetails': 'Fallen Trees - There was a major fallen tree on the trail that did require some climbing to get through',
#    'conditionDate': '2020-06-15 15:05:26'},
#   {'id': 7016574,
#    'name': 'Buckeye Trail - Cuyahoga Valley Section',
#    'type': 'Recommended Route',
#    'summary': 'The Buckeye Trail is a 1,444-mile loop that winds its way around Ohio, with 40 miles in CVNP.',
#    'difficulty': 'blueBlack',
#    'stars': 4.2,
#    'starVotes': 14,
#    'location': 'Bedford, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016574/buckeye-trail-cuyahoga-valley-section',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7025181_sqsmall_1554911704.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7025181_small_1554911704.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7025181_smallMed_1554911704.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7025181_medium_1554911704.jpg',
#    'length': 39.1,
#    'ascent': 2976,
#    'descent': -3204,
#    'high': 981,
#    'low': 623,
#    'longitude': -81.5341,
#    'latitude': 41.3803,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016460,
#    'name': 'Blue Hen Falls Trail',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'blue',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016460/blue-hen-falls-trail',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7010452_sqsmall_1554398524.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7010452_small_1554398524.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7010452_smallMed_1554398524.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7010452_medium_1554398524.jpg',
#    'length': 0.2,
#    'ascent': 0,
#    'descent': -77,
#    'high': 891,
#    'low': 815,
#    'longitude': -81.5726,
#    'latitude': 41.2564,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Mostly Dry, Some Mud',
#    'conditionDate': '2020-06-14 11:59:04'},
#   {'id': 7016778,
#    'name': 'Buckeye Trail: Boston to Pine Lane',
#    'type': 'Trail',
#    'summary': 'A challenging, hilly trail that stretches all the way around the state of Ohio.',
#    'difficulty': 'blueBlack',
#    'stars': 3.8,
#    'starVotes': 6,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016778/buckeye-trail-boston-to-pine-lane',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7025181_sqsmall_1554911704.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7025181_small_1554911704.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7025181_smallMed_1554911704.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7025181_medium_1554911704.jpg',
#    'length': 15.7,
#    'ascent': 896,
#    'descent': -818,
#    'high': 980,
#    'low': 670,
#    'longitude': -81.5568,
#    'latitude': 41.2614,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2020-06-14 14:47:28'},
#   {'id': 7016501,
#    'name': 'Hines Hill Connector',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'blue',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016501/hines-hill-connector',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.3,
#    'ascent': 0,
#    'descent': -74,
#    'high': 748,
#    'low': 673,
#    'longitude': -81.5561,
#    'latitude': 41.2671,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016555,
#    'name': 'Tree Farm Trail',
#    'type': 'Trail',
#    'summary': 'A great family-friendly trail with gently rolling hills and great views.',
#    'difficulty': 'blue',
#    'stars': 4.4,
#    'starVotes': 8,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016555/tree-farm-trail',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7015929_sqsmall_1554827044.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7015929_small_1554827044.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7015929_smallMed_1554827044.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7015929_medium_1554827044.jpg',
#    'length': 2.9,
#    'ascent': 134,
#    'descent': -133,
#    'high': 903,
#    'low': 841,
#    'longitude': -81.569,
#    'latitude': 41.2336,
#    'conditionStatus': 'Bad / Closed',
#    'conditionDetails': 'Muddy',
#    'conditionDate': '2020-04-22 16:12:04'},
#   {'id': 7016502,
#    'name': 'Horseshoe Pond Trail',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'green',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016502/horseshoe-pond-trail',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.1,
#    'ascent': 6,
#    'descent': -12,
#    'high': 906,
#    'low': 894,
#    'longitude': -81.5693,
#    'latitude': 41.2335,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016562,
#    'name': 'Wildlife Woods Connector',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'blue',
#    'stars': 4,
#    'starVotes': 1,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016562/wildlife-woods-connector',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.4,
#    'ascent': 129,
#    'descent': 0,
#    'high': 889,
#    'low': 760,
#    'longitude': -81.5366,
#    'latitude': 41.255,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016479,
#    'name': 'Connector Trail - Stanford to Towpath',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'green',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016479/connector-trail-stanford-to-towpath',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.1,
#    'ascent': 1,
#    'descent': -5,
#    'high': 663,
#    'low': 658,
#    'longitude': -81.557,
#    'latitude': 41.2705,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016478,
#    'name': 'Connector',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'black',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016478/connector',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0,
#    'ascent': 0,
#    'descent': -2,
#    'high': 674,
#    'low': 671,
#    'longitude': -81.5564,
#    'latitude': 41.2704,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016518,
#    'name': 'Peninsula Connector',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'black',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016518/peninsula-connector',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0,
#    'ascent': 0,
#    'descent': 0,
#    'high': 685,
#    'low': 684,
#    'longitude': -81.5504,
#    'latitude': 41.2432,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016517,
#    'name': 'Peninsula Connector',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'green',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016517/peninsula-connector',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.1,
#    'ascent': 3,
#    'descent': 0,
#    'high': 686,
#    'low': 684,
#    'longitude': -81.5504,
#    'latitude': 41.2429,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2020-06-14 14:47:28'},
#   {'id': 7016551,
#    'name': 'Stanford Trail',
#    'type': 'Trail',
#    'summary': 'Hilly, unpaved trail with several very steep sections.',
#    'difficulty': 'blueBlack',
#    'stars': 4.1,
#    'starVotes': 8,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016551/stanford-trail',
#    'imgSqSmall': 'https://img.youtube.com/vi/bPDMn3XoXOo/hqdefault.jpg',
#    'imgSmall': 'https://img.youtube.com/vi/bPDMn3XoXOo/hqdefault.jpg',
#    'imgSmallMed': 'https://img.youtube.com/vi/bPDMn3XoXOo/hqdefault.jpg',
#    'imgMedium': 'https://img.youtube.com/vi/bPDMn3XoXOo/hqdefault.jpg',
#    'length': 1.5,
#    'ascent': 300,
#    'descent': -117,
#    'high': 854,
#    'low': 670,
#    'longitude': -81.5559,
#    'latitude': 41.2711,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2020-06-16 09:38:21'},
#   {'id': 7016539,
#    'name': 'Quarry Trail Outer Loop',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'greenBlue',
#    'stars': 4,
#    'starVotes': 1,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016539/quarry-trail-outer-loop',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.2,
#    'ascent': 28,
#    'descent': -1,
#    'high': 813,
#    'low': 785,
#    'longitude': -81.5524,
#    'latitude': 41.2359,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016536,
#    'name': 'Quarry - Towpath Connector',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'greenBlue',
#    'stars': 3,
#    'starVotes': 1,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016536/quarry-towpath-connector',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.1,
#    'ascent': 0,
#    'descent': -25,
#    'high': 736,
#    'low': 710,
#    'longitude': -81.5526,
#    'latitude': 41.2325,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016552,
#    'name': 'Stanford Trail North Spur',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'blue',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Boston Heights, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016552/stanford-trail-north-spur',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.4,
#    'ascent': 0,
#    'descent': -27,
#    'high': 827,
#    'low': 800,
#    'longitude': -81.5476,
#    'latitude': 41.2737,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016531,
#    'name': 'Plateau Connector',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'greenBlue',
#    'stars': 4,
#    'starVotes': 1,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016531/plateau-connector',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.2,
#    'ascent': 17,
#    'descent': -26,
#    'high': 958,
#    'low': 932,
#    'longitude': -81.5706,
#    'latitude': 41.2239,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016469,
#    'name': 'Buckeye/Towpath Connector',
#    'type': 'Trail',
#    'summary': 'A short, somewhat utilitarian connector trail.',
#    'difficulty': 'green',
#    'stars': 2,
#    'starVotes': 1,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016469/buckeyetowpath-connector',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.6,
#    'ascent': 27,
#    'descent': -3,
#    'high': 669,
#    'low': 642,
#    'longitude': -81.5661,
#    'latitude': 41.2886,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016537,
#    'name': 'Quarry Trail',
#    'type': 'Trail',
#    'summary': 'A short trail paralleling the Buckeye Trail.',
#    'difficulty': 'blue',
#    'stars': 3.2,
#    'starVotes': 5,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016537/quarry-trail',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.7,
#    'ascent': 83,
#    'descent': -48,
#    'high': 814,
#    'low': 732,
#    'longitude': -81.554,
#    'latitude': 41.23,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016553,
#    'name': 'Stanford Trail Pond Spur',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'blue',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Boston Heights, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016553/stanford-trail-pond-spur',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0,
#    'ascent': 0,
#    'descent': -11,
#    'high': 805,
#    'low': 794,
#    'longitude': -81.5486,
#    'latitude': 41.2755,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016538,
#    'name': 'Quarry Trail Alt.',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'blue',
#    'stars': 3,
#    'starVotes': 1,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016538/quarry-trail-alt',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.1,
#    'ascent': 33,
#    'descent': -25,
#    'high': 770,
#    'low': 738,
#    'longitude': -81.5522,
#    'latitude': 41.2312,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016535,
#    'name': 'Quarry - Towpath Connector',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'greenBlue',
#    'stars': 3,
#    'starVotes': 1,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016535/quarry-towpath-connector',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.1,
#    'ascent': 0,
#    'descent': -14,
#    'high': 724,
#    'low': 710,
#    'longitude': -81.5522,
#    'latitude': 41.2309,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2020-05-20 17:29:56'},
#   {'id': 7016532,
#    'name': 'Plateau Connector Trail',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'blue',
#    'stars': 4,
#    'starVotes': 1,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016532/plateau-connector-trail',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.1,
#    'ascent': 54,
#    'descent': 0,
#    'high': 780,
#    'low': 726,
#    'longitude': -81.5581,
#    'latitude': 41.2246,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016541,
#    'name': 'Red Lock Connector',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'greenBlue',
#    'stars': 3,
#    'starVotes': 1,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016541/red-lock-connector',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.1,
#    'ascent': 0,
#    'descent': 0,
#    'high': 647,
#    'low': 646,
#    'longitude': -81.5639,
#    'latitude': 41.2896,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016489,
#    'name': 'East Rim Trail',
#    'type': 'Trail',
#    'summary': "Cuyahoga Valley National Park's first-ever mountain bike trail.",
#    'difficulty': 'black',
#    'stars': 3,
#    'starVotes': 2,
#    'location': 'Boston Heights, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016489/east-rim-trail',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7015963_sqsmall_1554827093.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7015963_small_1554827093.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7015963_smallMed_1554827093.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7015963_medium_1554827093.jpg',
#    'length': 2.3,
#    'ascent': 199,
#    'descent': -200,
#    'high': 963,
#    'low': 805,
#    'longitude': -81.5193,
#    'latitude': 41.2565,
#    'conditionStatus': 'Minor Issues',
#    'conditionDetails': '',
#    'conditionDate': '2020-04-01 14:30:37'},
#   {'id': 7016504,
#    'name': 'Jaite Wayside Connector',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'green',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016504/jaite-wayside-connector',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.2,
#    'ascent': 0,
#    'descent': -13,
#    'high': 658,
#    'low': 645,
#    'longitude': -81.572,
#    'latitude': 41.2887,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016512,
#    'name': 'Oak Hill Trail',
#    'type': 'Trail',
#    'summary': 'A beautiful shaded trail.',
#    'difficulty': 'greenBlue',
#    'stars': 4,
#    'starVotes': 8,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016512/oak-hill-trail',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7015967_sqsmall_1554827105.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7015967_small_1554827105.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7015967_smallMed_1554827105.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7015967_medium_1554827105.jpg',
#    'length': 1.4,
#    'ascent': 114,
#    'descent': -109,
#    'high': 978,
#    'low': 914,
#    'longitude': -81.5692,
#    'latitude': 41.2181,
#    'conditionStatus': 'Minor Issues',
#    'conditionDetails': 'Some Mud',
#    'conditionDate': '2020-05-25 13:27:29'},
#   {'id': 7050723,
#    'name': 'East Rim - Phase 2',
#    'type': 'Trail',
#    'summary': 'Some of the best rolling trail around.',
#    'difficulty': 'blue',
#    'stars': 3,
#    'starVotes': 2,
#    'location': 'Boston Heights, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7050723/east-rim-phase-2',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 4.4,
#    'ascent': 416,
#    'descent': -416,
#    'high': 961,
#    'low': 747,
#    'longitude': -81.5211,
#    'latitude': 41.2591,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016499,
#    'name': 'Hemlock Ravine Trail',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'blue',
#    'stars': 4,
#    'starVotes': 1,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016499/hemlock-ravine-trail',
#    'imgSqSmall': 'https://img.youtube.com/vi/QPmwPmNcFzc/hqdefault.jpg',
#    'imgSmall': 'https://img.youtube.com/vi/QPmwPmNcFzc/hqdefault.jpg',
#    'imgSmallMed': 'https://img.youtube.com/vi/QPmwPmNcFzc/hqdefault.jpg',
#    'imgMedium': 'https://img.youtube.com/vi/QPmwPmNcFzc/hqdefault.jpg',
#    'length': 0.3,
#    'ascent': 2,
#    'descent': -71,
#    'high': 912,
#    'low': 843,
#    'longitude': -81.5677,
#    'latitude': 41.2163,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016495,
#    'name': 'H.S. Wagner Daffodil Trail',
#    'type': 'Trail',
#    'summary': 'Needs Adoption',
#    'difficulty': 'greenBlue',
#    'stars': 5,
#    'starVotes': 1,
#    'location': 'Richfield, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016495/hs-wagner-daffodil-trail',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.6,
#    'ascent': 50,
#    'descent': -71,
#    'high': 1100,
#    'low': 1030,
#    'longitude': -81.6187,
#    'latitude': 41.2536,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7015784,
#    'name': 'H.S. Wagner Daffodil Trail',
#    'type': 'Trail',
#    'summary': 'Needs Adoption',
#    'difficulty': 'green',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Richfield, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7015784/hs-wagner-daffodil-trail',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.6,
#    'ascent': 50,
#    'descent': -73,
#    'high': 1102,
#    'low': 1029,
#    'longitude': -81.6187,
#    'latitude': 41.2536,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016388,
#    'name': 'Untitled Track 40',
#    'type': 'Trail',
#    'summary': 'Needs Adoption',
#    'difficulty': 'green',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Richfield, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016388/untitled-track-40',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.6,
#    'ascent': 49,
#    'descent': -70,
#    'high': 1100,
#    'low': 1030,
#    'longitude': -81.6187,
#    'latitude': 41.2536,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016533,
#    'name': 'Plateau Trail',
#    'type': 'Trail',
#    'summary': 'Tree-lined trail with several stunning ponds nearby.',
#    'difficulty': 'blue',
#    'stars': 4.3,
#    'starVotes': 21,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016533/plateau-trail',
#    'imgSqSmall': 'https://img.youtube.com/vi/QPmwPmNcFzc/hqdefault.jpg',
#    'imgSmall': 'https://img.youtube.com/vi/QPmwPmNcFzc/hqdefault.jpg',
#    'imgSmallMed': 'https://img.youtube.com/vi/QPmwPmNcFzc/hqdefault.jpg',
#    'imgMedium': 'https://img.youtube.com/vi/QPmwPmNcFzc/hqdefault.jpg',
#    'length': 4.6,
#    'ascent': 368,
#    'descent': -352,
#    'high': 1016,
#    'low': 783,
#    'longitude': -81.5759,
#    'latitude': 41.2201,
#    'conditionStatus': 'Minor Issues',
#    'conditionDetails': 'Some Mud',
#    'conditionDate': '2020-05-25 13:27:29'},
#   {'id': 7016464,
#    'name': 'Brandywine Gorge Boardwalk',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'blue',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Boston Heights, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016464/brandywine-gorge-boardwalk',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7018093_sqsmall_1554830303.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7018093_small_1554830303.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7018093_smallMed_1554830303.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7018093_medium_1554830303.jpg',
#    'length': 0.2,
#    'ascent': 5,
#    'descent': -37,
#    'high': 861,
#    'low': 827,
#    'longitude': -81.54,
#    'latitude': 41.2767,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2020-06-16 09:38:21'},
#   {'id': 7016465,
#    'name': 'Brandywine Gorge Boardwalk N. Spur',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'black',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Boston Heights, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016465/brandywine-gorge-boardwalk-n-spur',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7018093_sqsmall_1554830303.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7018093_small_1554830303.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7018093_smallMed_1554830303.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7018093_medium_1554830303.jpg',
#    'length': 0.1,
#    'ascent': 0,
#    'descent': -48,
#    'high': 835,
#    'low': 786,
#    'longitude': -81.5397,
#    'latitude': 41.2771,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016510,
#    'name': 'Mow Path Connector',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'green',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016510/mow-path-connector',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.1,
#    'ascent': 0,
#    'descent': -1,
#    'high': 1017,
#    'low': 1016,
#    'longitude': -81.5844,
#    'latitude': 41.2251,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016494,
#    'name': "Goosefeather Pond Fisherman's Path",
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'green',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016494/goosefeather-pond-fishermans-path',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.3,
#    'ascent': 6,
#    'descent': -7,
#    'high': 1023,
#    'low': 1017,
#    'longitude': -81.5829,
#    'latitude': 41.2238,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016463,
#    'name': 'Brandywine Gorge',
#    'type': 'Trail',
#    'summary': 'A 1.5-mile trek around the Brandywine Falls area.',
#    'difficulty': 'blue',
#    'stars': 4.3,
#    'starVotes': 7,
#    'location': 'Boston Heights, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016463/brandywine-gorge',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7018093_sqsmall_1554830303.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7018093_small_1554830303.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7018093_smallMed_1554830303.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7018093_medium_1554830303.jpg',
#    'length': 0.9,
#    'ascent': 66,
#    'descent': -162,
#    'high': 852,
#    'low': 693,
#    'longitude': -81.5384,
#    'latitude': 41.2767,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2020-06-16 09:38:21'},
#   {'id': 7016462,
#    'name': 'Boy Scout Connector',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'green',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016462/boy-scout-connector',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.1,
#    'ascent': 0,
#    'descent': -6,
#    'high': 738,
#    'low': 732,
#    'longitude': -81.5486,
#    'latitude': 41.2226,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016491,
#    'name': 'Furnace Run - Covered Bridge Connector',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'black',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016491/furnace-run-covered-bridge-connector',
#    'imgSqSmall': 'https://img.youtube.com/vi/I5eAmnwiOyo/hqdefault.jpg',
#    'imgSmall': 'https://img.youtube.com/vi/I5eAmnwiOyo/hqdefault.jpg',
#    'imgSmallMed': 'https://img.youtube.com/vi/I5eAmnwiOyo/hqdefault.jpg',
#    'imgMedium': 'https://img.youtube.com/vi/I5eAmnwiOyo/hqdefault.jpg',
#    'length': 0.1,
#    'ascent': 2,
#    'descent': -43,
#    'high': 988,
#    'low': 945,
#    'longitude': -81.5797,
#    'latitude': 41.2115,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7017757,
#    'name': 'Old Carriage Trail Connector',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'green',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Macedonia, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7017757/old-carriage-trail-connector',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.2,
#    'ascent': 0,
#    'descent': -18,
#    'high': 853,
#    'low': 835,
#    'longitude': -81.5589,
#    'latitude': 41.3017,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Mostly Dry',
#    'conditionDate': '2020-04-18 14:02:35'},
#   {'id': 7016549,
#    'name': 'Salt Run Trail Cutoff',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'green',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016549/salt-run-trail-cutoff',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.1,
#    'ascent': 0,
#    'descent': -29,
#    'high': 857,
#    'low': 828,
#    'longitude': -81.5406,
#    'latitude': 41.2213,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016515,
#    'name': 'Old Carriage Trail Side Loop',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'green',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Brecksville, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016515/old-carriage-trail-side-loop',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.2,
#    'ascent': 6,
#    'descent': -3,
#    'high': 798,
#    'low': 792,
#    'longitude': -81.5717,
#    'latitude': 41.3068,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7015797,
#    'name': 'Old Mill Trail',
#    'type': 'Trail',
#    'summary': 'Needs Adoption',
#    'difficulty': 'green',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Richfield, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7015797/old-mill-trail',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 1,
#    'ascent': 61,
#    'descent': -62,
#    'high': 1035,
#    'low': 998,
#    'longitude': -81.636,
#    'latitude': 41.2605,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016492,
#    'name': 'Furnace Run Spur',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'green',
#    'stars': 4,
#    'starVotes': 1,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016492/furnace-run-spur',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.1,
#    'ascent': 3,
#    'descent': -12,
#    'high': 787,
#    'low': 775,
#    'longitude': -81.5844,
#    'latitude': 41.2101,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016507,
#    'name': 'Langes Run Trail',
#    'type': 'Trail',
#    'summary': 'Part of a system of stunning trails that welcome hikers, runners, and horses alike.',
#    'difficulty': 'blueBlack',
#    'stars': 4.3,
#    'starVotes': 4,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016507/langes-run-trail',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 3.5,
#    'ascent': 394,
#    'descent': -366,
#    'high': 939,
#    'low': 730,
#    'longitude': -81.5454,
#    'latitude': 41.2123,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016560,
#    'name': 'Wetmore Trail',
#    'type': 'Trail',
#    'summary': 'Hikers, runners, and equestrians who love challenge and a little isolation will thrive on this trail',
#    'difficulty': 'blueBlack',
#    'stars': 4,
#    'starVotes': 17,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016560/wetmore-trail',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7015932_sqsmall_1554827052.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7015932_small_1554827052.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7015932_smallMed_1554827052.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7015932_medium_1554827052.jpg',
#    'length': 4.3,
#    'ascent': 472,
#    'descent': -585,
#    'high': 973,
#    'low': 743,
#    'longitude': -81.5454,
#    'latitude': 41.2123,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry, Some Mud, Fallen Trees',
#    'conditionDate': '2020-06-16 18:21:40'},
#   {'id': 7016480,
#    'name': 'Covered Bridge Trail',
#    'type': 'Trail',
#    'summary': 'An extension of Furnace Run Trail.',
#    'difficulty': 'blueBlack',
#    'stars': 3.8,
#    'starVotes': 4,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016480/covered-bridge-trail',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7061626_sqsmall_1565108903.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7061626_small_1565108903.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7061626_smallMed_1565108903.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7061626_medium_1565108903.jpg',
#    'length': 0.8,
#    'ascent': 258,
#    'descent': -9,
#    'high': 998,
#    'low': 749,
#    'longitude': -81.5811,
#    'latitude': 41.2042,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry, Some Mud',
#    'conditionDate': '2020-05-03 15:14:15'},
#   {'id': 7016470,
#    'name': 'Butlers Trail',
#    'type': 'Trail',
#    'summary': 'A connector trimming some of the mileage from the Langes Run Trail.',
#    'difficulty': 'green',
#    'stars': 2,
#    'starVotes': 1,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016470/butlers-trail',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.6,
#    'ascent': 1,
#    'descent': -157,
#    'high': 888,
#    'low': 730,
#    'longitude': -81.544,
#    'latitude': 41.2101,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016493,
#    'name': 'Furnace Run Trail',
#    'type': 'Trail',
#    'summary': 'A hidden gem with a steep climb.',
#    'difficulty': 'blueBlack',
#    'stars': 4.5,
#    'starVotes': 10,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016493/furnace-run-trail',
#    'imgSqSmall': 'https://img.youtube.com/vi/I5eAmnwiOyo/hqdefault.jpg',
#    'imgSmall': 'https://img.youtube.com/vi/I5eAmnwiOyo/hqdefault.jpg',
#    'imgSmallMed': 'https://img.youtube.com/vi/I5eAmnwiOyo/hqdefault.jpg',
#    'imgMedium': 'https://img.youtube.com/vi/I5eAmnwiOyo/hqdefault.jpg',
#    'length': 1.3,
#    'ascent': 223,
#    'descent': -161,
#    'high': 947,
#    'low': 747,
#    'longitude': -81.5832,
#    'latitude': 41.2042,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Some Mud',
#    'conditionDate': '2020-05-02 13:07:43'},
#   {'id': 7016542,
#    'name': 'Riding Run Trail',
#    'type': 'Trail',
#    'summary': 'Lots of steep climbs and technical portions—and incredible views.',
#    'difficulty': 'blueBlack',
#    'stars': 4.6,
#    'starVotes': 9,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016542/riding-run-trail',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7061631_sqsmall_1565109221.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7061631_small_1565109221.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7061631_smallMed_1565109221.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7061631_medium_1565109221.jpg',
#    'length': 3.2,
#    'ascent': 422,
#    'descent': -383,
#    'high': 1013,
#    'low': 749,
#    'longitude': -81.5838,
#    'latitude': 41.204,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry, Some Mud',
#    'conditionDate': '2020-05-03 15:14:15'},
#   {'id': 7016520,
#    'name': 'Perkins Trail',
#    'type': 'Trail',
#    'summary': 'A hilly, technical trek through a quiet, scenic area of the park.',
#    'difficulty': 'black',
#    'stars': 4.5,
#    'starVotes': 11,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016520/perkins-trail',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7015972_sqsmall_1554827118.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7015972_small_1554827118.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7015972_smallMed_1554827118.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7015972_medium_1554827118.jpg',
#    'length': 2.6,
#    'ascent': 427,
#    'descent': -291,
#    'high': 1023,
#    'low': 748,
#    'longitude': -81.5845,
#    'latitude': 41.2038,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7015768,
#    'name': 'Buttonwood Trail',
#    'type': 'Trail',
#    'summary': 'Needs Adoption',
#    'difficulty': 'green',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Richfield, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7015768/buttonwood-trail',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.9,
#    'ascent': 18,
#    'descent': -53,
#    'high': 1038,
#    'low': 991,
#    'longitude': -81.6376,
#    'latitude': 41.267,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016548,
#    'name': 'Salt Run Trail',
#    'type': 'Trail',
#    'summary': 'A hilly, beautiful trail.',
#    'difficulty': 'blueBlack',
#    'stars': 4.5,
#    'starVotes': 28,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016548/salt-run-trail',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7015964_sqsmall_1554827097.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7015964_small_1554827097.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7015964_smallMed_1554827097.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7015964_medium_1554827097.jpg',
#    'length': 3.4,
#    'ascent': 466,
#    'descent': -474,
#    'high': 905,
#    'low': 716,
#    'longitude': -81.5297,
#    'latitude': 41.2165,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry, Some Mud',
#    'conditionDate': '2020-06-12 17:37:21'},
#   {'id': 7015812,
#    'name': 'Rock Creek Trail',
#    'type': 'Trail',
#    'summary': 'Easy, wide hiking path about one mile long, connects to another one-mile loop.',
#    'difficulty': 'green',
#    'stars': 4,
#    'starVotes': 1,
#    'location': 'Richfield, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7015812/rock-creek-trail',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 1.3,
#    'ascent': 48,
#    'descent': -49,
#    'high': 1057,
#    'low': 1024,
#    'longitude': -81.6376,
#    'latitude': 41.2685,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016503,
#    'name': 'Howe Hale Connector Trail',
#    'type': 'Trail',
#    'summary': 'An easy trail from Hunt House to Hale Farm.',
#    'difficulty': 'blue',
#    'stars': 3,
#    'starVotes': 1,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016503/howe-hale-connector-trail',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 1.1,
#    'ascent': 103,
#    'descent': -43,
#    'high': 826,
#    'low': 724,
#    'longitude': -81.5743,
#    'latitude': 41.1935,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016336,
#    'name': 'Rock Creek Cutoff Trail',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'green',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Richfield, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016336/rock-creek-cutoff-trail',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.1,
#    'ascent': 10,
#    'descent': -6,
#    'high': 1042,
#    'low': 1032,
#    'longitude': -81.6386,
#    'latitude': 41.2683,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016461,
#    'name': 'Boston Run Trail',
#    'type': 'Trail',
#    'summary': 'Perfect for exploring the space around Happy Days Lodge, no matter your ability.',
#    'difficulty': 'blue',
#    'stars': 3.2,
#    'starVotes': 9,
#    'location': 'Boston Heights, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016461/boston-run-trail',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7015032_sqsmall_1554825695.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7015032_small_1554825695.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7015032_smallMed_1554825695.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7015032_medium_1554825695.jpg',
#    'length': 3.2,
#    'ascent': 284,
#    'descent': -270,
#    'high': 979,
#    'low': 885,
#    'longitude': -81.5071,
#    'latitude': 41.232,
#    'conditionStatus': 'Minor Issues',
#    'conditionDetails': 'Muddy',
#    'conditionDate': '2020-03-24 14:53:45'},
#   {'id': 7016490,
#    'name': 'Forest Point Trail',
#    'type': 'Trail',
#    'summary': 'A family-friendly trail and picnicking area near the Ledges.',
#    'difficulty': 'green',
#    'stars': 4,
#    'starVotes': 1,
#    'location': 'Boston Heights, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016490/forest-point-trail',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7048904_sqsmall_1555540225.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7048904_small_1555540225.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7048904_smallMed_1555540225.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7048904_medium_1555540225.jpg',
#    'length': 0.6,
#    'ascent': 13,
#    'descent': -32,
#    'high': 928,
#    'low': 896,
#    'longitude': -81.5149,
#    'latitude': 41.226,
#    'conditionStatus': 'Minor Issues',
#    'conditionDetails': 'Muddy, Fallen Trees',
#    'conditionDate': '2020-03-23 14:27:18'},
#   {'id': 7017462,
#    'name': 'Virginia Kendall Connector',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'green',
#    'stars': 2,
#    'starVotes': 1,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7017462/virginia-kendall-connector',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.4,
#    'ascent': 14,
#    'descent': 0,
#    'high': 914,
#    'low': 900,
#    'longitude': -81.531,
#    'latitude': 41.2137,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7015895,
#    'name': 'Lake Trail',
#    'type': 'Trail',
#    'summary': 'Short loop around Kendall Lake which features lake edge, marshland and woods.',
#    'difficulty': 'blue',
#    'stars': 4,
#    'starVotes': 10,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7015895/lake-trail',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7013714_sqsmall_1554823004.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7013714_small_1554823004.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7013714_smallMed_1554823004.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7013714_medium_1554823004.jpg',
#    'length': 1.1,
#    'ascent': 58,
#    'descent': -58,
#    'high': 856,
#    'low': 812,
#    'longitude': -81.5239,
#    'latitude': 41.2187,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry, Some Mud',
#    'conditionDate': '2020-06-12 17:37:21'},
#   {'id': 7016497,
#    'name': 'Haskell Run Trail',
#    'type': 'Trail',
#    'summary': 'Perfect for exploring the space around Happy Days Lodge, no matter your ability.',
#    'difficulty': 'blue',
#    'stars': 3,
#    'starVotes': 3,
#    'location': 'Boston Heights, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016497/haskell-run-trail',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7014529_sqsmall_1554824446.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7014529_small_1554824446.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7014529_smallMed_1554824446.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7014529_medium_1554824446.jpg',
#    'length': 0.6,
#    'ascent': 84,
#    'descent': -80,
#    'high': 939,
#    'low': 861,
#    'longitude': -81.5088,
#    'latitude': 41.23,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Muddy - Just a little wet from recent rains but otherwise a lovely trail.',
#    'conditionDate': '2020-04-10 21:06:39'},
#   {'id': 7016996,
#    'name': 'Connector Trail',
# ...
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.1,
#    'ascent': 0,
#    'descent': -19,
#    'high': 757,
#    'low': 738,
#    'longitude': -81.587,
#    'latitude': 41.1902,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016530,
#    'name': 'Pinery Narrows (Seg. 9)',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'green',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Brecksville, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016530/pinery-narrows-seg-9',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.2,
#    'ascent': 7,
#    'descent': -3,
#    'high': 643,
#    'low': 636,
#    'longitude': -81.5879,
#    'latitude': 41.3187,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016554,
#    'name': 'Tabletop Trail',
#    'type': 'Trail',
#    'summary': 'A short, new trail, recently rebuilt after 10+ years of closure.',
#    'difficulty': 'blue',
#    'stars': 4,
#    'starVotes': 1,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016554/tabletop-trail',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7015966_sqsmall_1554827102.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7015966_small_1554827102.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7015966_smallMed_1554827102.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7015966_medium_1554827102.jpg',
#    'length': 0.7,
#    'ascent': 88,
#    'descent': -78,
#    'high': 932,
#    'low': 846,
#    'longitude': -81.5257,
#    'latitude': 41.2056,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016474,
#    'name': 'Campground Connector',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'green',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016474/campground-connector',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.5,
#    'ascent': 1,
#    'descent': -75,
#    'high': 823,
#    'low': 748,
#    'longitude': -81.5899,
#    'latitude': 41.1916,
#    'conditionStatus': 'Bad / Closed',
#    'conditionDetails': 'Some Mud',
#    'conditionDate': '2020-06-10 19:08:52'},
#   {'id': 7016546,
#    'name': 'Salamander Buckeye Connector',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'green',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Brecksville, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016546/salamander-buckeye-connector',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.1,
#    'ascent': 2,
#    'descent': -12,
#    'high': 797,
#    'low': 785,
#    'longitude': -81.6026,
#    'latitude': 41.3106,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016511,
#    'name': 'My Mountain Scenic Overlook',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'green',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Brecksville, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016511/my-mountain-scenic-overlook',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.1,
#    'ascent': 7,
#    'descent': -5,
#    'high': 769,
#    'low': 762,
#    'longitude': -81.5967,
#    'latitude': 41.3154,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016528,
#    'name': 'Pinery Narrows (Seg. 7)',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'green',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Brecksville, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016528/pinery-narrows-seg-7',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7019130_sqsmall_1554836500.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7019130_small_1554836500.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7019130_smallMed_1554836500.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7019130_medium_1554836500.jpg',
#    'length': 0.2,
#    'ascent': 10,
#    'descent': 0,
#    'high': 635,
#    'low': 625,
#    'longitude': -81.5866,
#    'latitude': 41.3231,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016485,
#    'name': 'Deer Lick-Buckeye Connector',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'black',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Brecksville, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016485/deer-lick-buckeye-connector',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0,
#    'ascent': 2,
#    'descent': 0,
#    'high': 662,
#    'low': 660,
#    'longitude': -81.601,
#    'latitude': 41.3159,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016527,
#    'name': 'Pinery Narrows (Seg. 6)',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'green',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Brecksville, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016527/pinery-narrows-seg-6',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.3,
#    'ascent': 3,
#    'descent': -4,
#    'high': 630,
#    'low': 626,
#    'longitude': -81.5903,
#    'latitude': 41.3305,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016468,
#    'name': 'Buckeye Sports Connector',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'green',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Boston Heights, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016468/buckeye-sports-connector',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.6,
#    'ascent': 17,
#    'descent': -26,
#    'high': 1000,
#    'low': 977,
#    'longitude': -81.5086,
#    'latitude': 41.203,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016526,
#    'name': 'Pinery Narrows (Seg. 5)',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'green',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Brecksville, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016526/pinery-narrows-seg-5',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.3,
#    'ascent': 8,
#    'descent': -3,
#    'high': 630,
#    'low': 622,
#    'longitude': -81.5879,
#    'latitude': 41.3354,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016476,
#    'name': 'Chippewa Creek Trail',
#    'type': 'Trail',
#    'summary': 'A short, pleasant, side trail branching off from the Hemlock-Chippewa Trail.',
#    'difficulty': 'greenBlue',
#    'stars': 4,
#    'starVotes': 2,
#    'location': 'Brecksville, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016476/chippewa-creek-trail',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 1,
#    'ascent': 5,
#    'descent': -33,
#    'high': 679,
#    'low': 647,
#    'longitude': -81.6087,
#    'latitude': 41.32,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016483,
#    'name': 'Deer Lick',
#    'type': 'Trail',
#    'summary': 'A short spur adding interest to a longer loop',
#    'difficulty': 'blueBlack',
#    'stars': 3,
#    'starVotes': 2,
#    'location': 'Brecksville, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016483/deer-lick',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7016915_sqsmall_1554828525.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7016915_small_1554828525.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7016915_smallMed_1554828525.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7016915_medium_1554828525.jpg',
#    'length': 0.4,
#    'ascent': 40,
#    'descent': -42,
#    'high': 861,
#    'low': 821,
#    'longitude': -81.6156,
#    'latitude': 41.3167,
#    'conditionStatus': 'Minor Issues',
#    'conditionDetails': 'Muddy - Quite a few large muddy patches after some localized rains.',
#    'conditionDate': '2020-04-28 22:09:38'},
#   {'id': 7016456,
#    'name': 'Adam Run Trail',
#    'type': 'Trail',
#    'summary': 'Multiple stream crossings and a quality uphill climb make this trail a must visit.',
#    'difficulty': 'blue',
#    'stars': 4.8,
#    'starVotes': 9,
#    'location': 'Peninsula, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016456/adam-run-trail',
#    'imgSqSmall': 'https://img.youtube.com/vi/Rt9vghC6vOE/hqdefault.jpg',
#    'imgSmall': 'https://img.youtube.com/vi/Rt9vghC6vOE/hqdefault.jpg',
#    'imgSmallMed': 'https://img.youtube.com/vi/Rt9vghC6vOE/hqdefault.jpg',
#    'imgMedium': 'https://img.youtube.com/vi/Rt9vghC6vOE/hqdefault.jpg',
#    'length': 3.1,
#    'ascent': 295,
#    'descent': -287,
#    'high': 997,
#    'low': 752,
#    'longitude': -81.55,
#    'latitude': 41.1691,
#    'conditionStatus': 'Minor Issues',
#    'conditionDetails': 'Muddy',
#    'conditionDate': '2020-05-18 15:41:12'},
#   {'id': 7016513,
#    'name': 'Ohio & Erie Canal Towpath Trail',
#    'type': 'Trail',
#    'summary': 'An iconic trail along the Ohio & Erie Canalway. The backbone of CVNP.',
#    'difficulty': 'greenBlue',
#    'stars': 4.3,
#    'starVotes': 9,
#    'location': 'Montrose-Ghent, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016513/ohio-erie-canal-towpath-trail',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7025181_sqsmall_1554911704.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7025181_small_1554911704.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7025181_smallMed_1554911704.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7025181_medium_1554911704.jpg',
#    'length': 20.6,
#    'ascent': 109,
#    'descent': -248,
#    'high': 753,
#    'low': 605,
#    'longitude': -81.5735,
#    'latitude': 41.1584,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Mostly Dry',
#    'conditionDate': '2020-05-19 13:38:49'},
#   {'id': 7016534,
#    'name': 'Prairie Loop',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'green',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Brecksville, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016534/prairie-loop',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.4,
#    'ascent': 17,
#    'descent': -20,
#    'high': 855,
#    'low': 835,
#    'longitude': -81.6159,
#    'latitude': 41.3194,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2020-05-31 16:17:58'},
#   {'id': 7016487,
#    'name': 'Deer Run Trail',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'blue',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Montrose-Ghent, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016487/deer-run-trail',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.5,
#    'ascent': 29,
#    'descent': -223,
#    'high': 985,
#    'low': 783,
#    'longitude': -81.5888,
#    'latitude': 41.1697,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Some Mud - Really heavy rains yesterday but the trail is decently dry.',
#    'conditionDate': '2020-05-16 09:25:42'},
#   {'id': 7016496,
#    'name': 'Harriet L. Keeler Memorial',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'green',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Brecksville, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016496/harriet-l-keeler-memorial',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0,
#    'ascent': 0,
#    'descent': 0,
#    'high': 856,
#    'low': 856,
#    'longitude': -81.619,
#    'latitude': 41.318,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016525,
#    'name': 'Pinery Narrows (Seg. 4)',
#    'type': 'Connector',
#    'summary': '',
#    'difficulty': 'green',
#    'stars': 0,
#    'starVotes': 0,
#    'location': 'Walton Hills, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016525/pinery-narrows-seg-4',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 0.4,
#    'ascent': 5,
#    'descent': -5,
#    'high': 625,
#    'low': 620,
#    'longitude': -81.5874,
#    'latitude': 41.3419,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016458,
#    'name': 'Bike & Hike Trail',
#    'type': 'Trail',
#    'summary': 'The Bike and Hike Trail is a nice paved trail that is relatively flat.',
#    'difficulty': 'greenBlue',
#    'stars': 3.5,
#    'starVotes': 2,
#    'location': 'Walton Hills, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016458/bike-hike-trail',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7018093_sqsmall_1554830303.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7018093_small_1554830303.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7018093_smallMed_1554830303.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7018093_medium_1554830303.jpg',
#    'length': 33.2,
#    'ascent': 799,
#    'descent': -597,
#    'high': 1118,
#    'low': 841,
#    'longitude': -81.5686,
#    'latitude': 41.3578,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016500,
#    'name': 'Hemlock-Chippewa',
#    'type': 'Trail',
#    'summary': 'A shaded, rolling trail near Chippewa Creek.',
#    'difficulty': 'greenBlue',
#    'stars': 3.5,
#    'starVotes': 2,
#    'location': 'Brecksville, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016500/hemlock-chippewa',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 1.4,
#    'ascent': 39,
#    'descent': -207,
#    'high': 845,
#    'low': 657,
#    'longitude': -81.6218,
#    'latitude': 41.3199,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7078471,
#    'name': 'North Fork Trail',
#    'type': 'Trail',
#    'summary': 'Great little getaway provided by the Township of Bath.',
#    'difficulty': 'blue',
#    'stars': 5,
#    'starVotes': 1,
#    'location': 'Montrose-Ghent, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7078471/north-fork-trail',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 1.4,
#    'ascent': 37,
#    'descent': -78,
#    'high': 1043,
#    'low': 991,
#    'longitude': -81.6554,
#    'latitude': 41.187,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7016779,
#    'name': 'Buckeye Trail: Station Rd to Boston',
#    'type': 'Trail',
#    'summary': 'A challenging, hilly trail that stretches all the way around the state of Ohio.',
#    'difficulty': 'blueBlack',
#    'stars': 3.7,
#    'starVotes': 3,
#    'location': 'Bedford, Ohio',
#    'url': 'https://www.hikingproject.com/trail/7016779/buckeye-trail-station-rd-to-boston',
#    'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7019130_sqsmall_1554836500.jpg',
#    'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7019130_small_1554836500.jpg',
#    'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7019130_smallMed_1554836500.jpg',
#    'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7019130_medium_1554836500.jpg',
#    'length': 23.2,
#    'ascent': 1809,
#    'descent': -2115,
#    'high': 974,
#    'low': 623,
#    'longitude': -81.5341,
#    'latitude': 41.3803,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'}],
#  'success': 1}

# %%
test = response['trails'][0]['summary']
print(test)
# Out:
# An out-and-back trail that follows a creek between two waterfalls.

# %%
response['trails'][0]['summary']
# Out:
# 'An out-and-back trail that follows a creek between two waterfalls.'

# %%
for i in range(len(response['trails'])):
    trail_id.append(response['trails'][i]['id'])
    name.append(response['trails'][i]['name'])
    trail_type.append(response['trails'][i]['type'])
    summary.append(response['trails'][i]['summary'])
    difficulty.append(response['trails'][i]['difficulty'])
    stars.append(response['trails'][i]['stars'])
    starVotes.append(response['trails'][i]['starVotes'])
    location.append(response['trails'][i]['location'])
    url.append(response['trails'][i]['url'])
    imgSqSmall.append(response['trails'][i]['imgSqSmall'])
    imgSmall.append(response['trails'][i]['imgSmall'])
    imgSmallMed.append(response['trails'][i]['imgSmallMed'])
    imgMedium.append(response['trails'][i]['imgMedium'])
    length.append(response['trails'][i]['length'])
    ascent.append(response['trails'][i]['ascent'])
    descent.append(response['trails'][i]['descent'])
    high.append(response['trails'][i]['high'])
    low.append(response['trails'][i]['low'])
    longitude.append(response['trails'][i]['longitude'])
    latitude.append(response['trails'][i]['latitude'])
    conditionStatus.append(response['trails'][i]['conditionStatus'])
    conditionDetails.append(response['trails'][i]['conditionDetails'])
    conditionDate.append(response['trails'][i]['conditionDate'])

# %%
trail_df = pd.DataFrame({'trail_id': trail_id,
'name' : name,
'trail_type' : trail_type,
'summary' : summary,
'difficulty' : difficulty,
'stars' : stars,
'starVotes' : starVotes,
'location' : location,
'url': url,
'imgSqSmall' : imgSqSmall,
'imgSmall' : imgSmall,
'imgSmallMed' : imgSmallMed,
'imgMedium' : imgMedium,
'length, miles' : length,
'ascent, ft': ascent,
'descent, ft' : descent,
'high, ft' : high,
'low, ft': low,
'latitude' : latitude,
'longitude' : longitude,
'conditionStatus' : conditionStatus,
'conditionDetails' : conditionDetails,
'conditionDate' : conditionDate})

# %%
trail_df
# Out:
#      trail_id                                     name         trail_type  \
# 0     7013161                     Blue Hen Falls Trail  Recommended Route
# 1     7017937                    Brandywine Falls Loop  Recommended Route
# 2     7016992                Ledges to Pine Grove Loop  Recommended Route
# 3     7015894                Deer Lick Cave Loop Trail  Recommended Route
# 4     7016574  Buckeye Trail - Cuyahoga Valley Section  Recommended Route
# ..        ...                                      ...                ...
# 99    7016525                  Pinery Narrows (Seg. 4)          Connector
# 100   7016458                        Bike & Hike Trail              Trail
# 101   7016500                         Hemlock-Chippewa              Trail
# 102   7078471                         North Fork Trail              Trail
# 103   7016779      Buckeye Trail: Station Rd to Boston              Trail
#
#                                                summary difficulty  stars  \
# 0    An out-and-back trail that follows a creek bet...       blue    4.2
# 1    Enjoy a scenic tour of the area surrounding on...  greenBlue    4.4
# 2    See one of CVNP's most iconic trails plus a li...       blue    4.5
# 3    A wooded loop around the Brecksville Reservati...       blue    4.1
# 4    The Buckeye Trail is a 1,444-mile loop that wi...  blueBlack    4.2
# ..                                                 ...        ...    ...
# 99                                                          green    0.0
# 100  The Bike and Hike Trail is a nice paved trail ...  greenBlue    3.5
# 101       A shaded, rolling trail near Chippewa Creek.  greenBlue    3.5
# 102  Great little getaway provided by the Township ...       blue    5.0
# 103  A challenging, hilly trail that stretches all ...  blueBlack    3.7
#
#      starVotes              location  \
# 0           27       Peninsula, Ohio
# 1           47  Boston Heights, Ohio
# 2           47  Boston Heights, Ohio
# 3           20     Brecksville, Ohio
# 4           14         Bedford, Ohio
# ..         ...                   ...
# 99           0    Walton Hills, Ohio
# 100          2    Walton Hills, Ohio
# 101          2     Brecksville, Ohio
# 102          1  Montrose-Ghent, Ohio
# 103          3         Bedford, Ohio
#
#                                                    url  \
# 0    https://www.hikingproject.com/trail/7013161/bl...
# 1    https://www.hikingproject.com/trail/7017937/br...
# 2    https://www.hikingproject.com/trail/7016992/le...
# 3    https://www.hikingproject.com/trail/7015894/de...
# 4    https://www.hikingproject.com/trail/7016574/bu...
# ..                                                 ...
# 99   https://www.hikingproject.com/trail/7016525/pi...
# 100  https://www.hikingproject.com/trail/7016458/bi...
# 101  https://www.hikingproject.com/trail/7016500/he...
# 102  https://www.hikingproject.com/trail/7078471/no...
# 103  https://www.hikingproject.com/trail/7016779/bu...
#
#                                             imgSqSmall  ... length, miles  \
# 0    https://cdn2.apstatic.com/photos/hike/7010452_...  ...           1.2
# 1    https://cdn2.apstatic.com/photos/hike/7018093_...  ...           1.4
# 2    https://cdn2.apstatic.com/photos/hike/7015930_...  ...           4.0
# 3    https://cdn2.apstatic.com/photos/hike/7016916_...  ...           3.7
# 4    https://cdn2.apstatic.com/photos/hike/7025181_...  ...          39.1
# ..                                                 ...  ...           ...
# 99                                                      ...           0.4
# 100  https://cdn2.apstatic.com/photos/hike/7018093_...  ...          33.2
# 101                                                     ...           1.4
# 102                                                     ...           1.4
# 103  https://cdn2.apstatic.com/photos/hike/7019130_...  ...          23.2
#
#     ascent, ft descent, ft  high, ft  low, ft  latitude  longitude  \
# 0          146        -147       879      732   41.2570   -81.5726
# 1          179        -180       857      695   41.2767   -81.5400
# 2          230        -232      1054      881   41.2240   -81.5106
# 3          480        -484       858      657   41.3054   -81.6092
# 4         2976       -3204       981      623   41.3803   -81.5341
# ..         ...         ...       ...      ...       ...        ...
# 99           5          -5       625      620   41.3419   -81.5874
# 100        799        -597      1118      841   41.3578   -81.5686
# 101         39        -207       845      657   41.3199   -81.6218
# 102         37         -78      1043      991   41.1870   -81.6554
# 103       1809       -2115       974      623   41.3803   -81.5341
#
#      conditionStatus                                   conditionDetails  \
# 0          All Clear                               Mostly Dry, Some Mud
# 1          All Clear                                                Dry
# 2          All Clear                                                Dry
# 3       Minor Issues  Fallen Trees - There was a major fallen tree o...
# 4            Unknown                                               None
# ..               ...                                                ...
# 99           Unknown                                               None
# 100          Unknown                                               None
# 101          Unknown                                               None
# 102          Unknown                                               None
# 103          Unknown                                               None
#
#            conditionDate
# 0    2020-06-14 11:59:04
# 1    2020-06-16 09:38:21
# 2    2020-06-15 11:43:05
# 3    2020-06-15 15:05:26
# 4    1970-01-01 00:00:00
# ..                   ...
# 99   1970-01-01 00:00:00
# 100  1970-01-01 00:00:00
# 101  1970-01-01 00:00:00
# 102  1970-01-01 00:00:00
# 103  1970-01-01 00:00:00
#
# [104 rows x 23 columns]

# %%
trail_df.loc[trail_df['trail_id'] == 7078471,:]['url']
# Out:
# 102    https://www.hikingproject.com/trail/7078471/no...
# Name: url, dtype: object

# %%
trail_df['conditionStatus'].unique()
# Out:
# array(['All Clear', 'Minor Issues', 'Unknown', 'Bad / Closed'],
#       dtype=object)

# %%
response['trails'][0]
# Out:
# {'id': 7013161,
#  'name': 'Blue Hen Falls Trail',
#  'type': 'Recommended Route',
#  'summary': 'An out-and-back trail that follows a creek between two waterfalls.',
#  'difficulty': 'blue',
#  'stars': 4.2,
#  'starVotes': 27,
#  'location': 'Peninsula, Ohio',
#  'url': 'https://www.hikingproject.com/trail/7013161/blue-hen-falls-trail',
#  'imgSqSmall': 'https://cdn2.apstatic.com/photos/hike/7010452_sqsmall_1554398524.jpg',
#  'imgSmall': 'https://cdn2.apstatic.com/photos/hike/7010452_small_1554398524.jpg',
#  'imgSmallMed': 'https://cdn2.apstatic.com/photos/hike/7010452_smallMed_1554398524.jpg',
#  'imgMedium': 'https://cdn2.apstatic.com/photos/hike/7010452_medium_1554398524.jpg',
#  'length': 1.2,
#  'ascent': 146,
#  'descent': -147,
#  'high': 879,
#  'low': 732,
#  'longitude': -81.5726,
#  'latitude': 41.257,
#  'conditionStatus': 'All Clear',
#  'conditionDetails': 'Mostly Dry, Some Mud',
#  'conditionDate': '2020-06-14 11:59:04'}

# %%
park_df
# Out:
#               Name                 Location       coordinates    lat     lon  \
# 0           Acadia                    Maine   44.35°N 68.21°W  44.35  -68.21
# 1   American Samoa           American Samoa  14.25°S 170.68°W -14.25 -170.68
# 2           Arches                     Utah  38.68°N 109.57°W  38.68 -109.57
# 3         Badlands             South Dakota  43.75°N 102.50°W  43.75 -102.50
# 4         Big Bend                    Texas  29.25°N 103.25°W  29.25 -103.25
# ..             ...                      ...               ...    ...     ...
# 57       Wind Cave             South Dakota  43.57°N 103.48°W  43.57 -103.48
# 58        Wrangell                   Alaska  61.00°N 142.00°W  61.00 -142.00
# 59     Yellowstone  Wyoming, Montana, Idaho  44.60°N 110.50°W  44.60 -110.50
# 60        Yosemite               California  37.83°N 119.50°W  37.83 -119.50
# 61            Zion                     Utah  37.30°N 113.05°W  37.30 -113.05
#
#    Date established as park                        Area, acres   area, acres  \
# 0                 26-Feb-19        49,076.63 acres (198.6 km2)     49,076.63
# 1                 31-Oct-88          8,256.67 acres (33.4 km2)      8,256.67
# 2                 12-Nov-71        76,678.98 acres (310.3 km2)     76,678.98
# 3                 10-Nov-78       242,755.94 acres (982.4 km2)    242,755.94
# 4                 12-Jun-44     801,163.21 acres (3,242.2 km2)    801,163.21
# ..                      ...                                ...           ...
# 57                 9-Jan-03        33,970.84 acres (137.5 km2)     33,970.84
# 58                 2-Dec-80  8,323,146.48 acres (33,682.6 km2)  8,323,146.48
# 59            March 1, 1872   2,219,790.71 acres (8,983.2 km2)  2,219,790.71
# 60          October 1, 1890     761,747.50 acres (3,082.7 km2)    761,747.50
# 61                19-Nov-19       147,242.66 acres (595.9 km2)    147,242.66
#
#    area, km^2 Recreation visitors  \
# 0       198.6           3,537,575
# 1        33.4              28,626
# 2       310.3           1,663,557
# 3       982.4           1,008,942
# 4     3,242.2             440,091
# ..        ...                 ...
# 57      137.5             656,397
# 58   33,682.6              79,450
# 59    8,983.2           4,115,000
# 60    3,082.7           4,009,436
# 61      595.9           4,320,033
#
#                                           Description
# 0   Covering most of Mount Desert Island and other...
# 1   The southernmost national park is on three Sam...
# 2   This site features more than 2,000 natural san...
# 3   The Badlands are a collection of buttes, pinna...
# 4   Named for the prominent bend in the Rio Grande...
# ..                                                ...
# 57  Wind Cave is distinctive for its calcite fin f...
# 58  An over 8 million acres (32,375 km2) plot of m...
# 59  Situated on the Yellowstone Caldera, the park ...
# 60  Yosemite features sheer granite cliffs, except...
# 61  Located at the junction of the Colorado Platea...
#
# [62 rows x 11 columns]

# %%
trail_df.to_csv('trail_for_CVNP.csv')
